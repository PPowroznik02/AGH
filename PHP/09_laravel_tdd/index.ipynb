# %% [markdown]
# # PHP

# %% [markdown]
# ## 9. Laravel TDD

# %% [markdown]
# This project was started from the solution of the previous exercise.
#
# #### Laravel Breeze
#
# The [Laravel Breeze](https://laravel.com/docs/11.x/starter-kits#laravel-breeze) package was installed using the ```composer require laravel/breeze --dev``` and ```php artisan breeze:install``` commands. This package enables user registration and logging into the application.
#
# An example user is added through the [database/seeders/UsersSeeder.php](/edit/09_laravel_tdd/project/database/seeders/UsersSeeder.php) class generated using the ```php artisan make:seeder UsersSeeder``` command. The database seeding is done during the execution of the ```php artisan db:seed``` command before the database dump.
#
# The logging-in is tested in the [tests_codeception/Acceptance/Test02_LoginCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test02_LoginCest.php) test.
#
# Extensive testing is also done when executing the ```php artisan test``` command because the ```php artisan breeze:install``` command added many additional tests.
#
# Because there are many tests, it was possible to safely clean up PHPStan issues in the code added by ```php artisan breeze:install``` command.
#
# #### Laravel Markdown
#
# The next change done in the project was the use of the [graham-campbell/markdown](https://packagist.org/packages/graham-campbell/markdown) package, which adds support for Markdown in Laravel.
#
# The package was installed using the ```composer require graham-campbell/markdown``` command.
# The [tests_codeception/Acceptance/Test01_CommentsCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test01_CommentsCest.php) test was extended to test for adding some **bold** text. The [resources/views/comment/show.blade.php](/edit/09_laravel_tdd/project/resources/views/comment/show.blade.php) view was updated to render the Markdown.
#
# #### Tailwind CSS
#
# The [tailwindcss](https://tailwindcss.com/) is used to style the front end. Some examples of how to build components in HTML with CSS can be found on, e.g., [flowbite](https://flowbite.com/) site.
#
# However, I am not an expert here, so there might be much better resources ;)

# %% [markdown]
# Start database:

# %%
! docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test --env MYSQL_USER=test --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
# Out:
# docker: Error response from daemon: Conflict. The container name "/mysql" is already in use by container "905d70b0d68e33325cceaeaf9035a96c65d71fe7c97f18a0dec0e83e1808cc1a". You have to remove (or rename) that container to be able to reuse that name.
# See 'docker run --help'.

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306" 2> /dev/null; do sleep 1; done; echo "Done.";
# Out:
# Done.

# %% [markdown]
# Install the CPD checker globally:

# %%
! composer global require sebastian/phpcpd 6.0.3 -dev --no-interaction
# Out:
# In Application.php line 437:
#
#   Invalid working directory specified, ev does not exist.

# %% [markdown]
# You can test your solution using included tests:

# %%
# %cd project
# Out:
# /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project

# %%
! composer install
# Out:
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Nothing to install, update or remove
# Generating optimized autoload files
# > Illuminate\Foundation\ComposerScripts::postAutoloadDump
# > @php artisan package:discover --ansi
#
#    INFO  Discovering packages.
#
#   graham-campbell/markdown .............................................. DONE
#   laravel/breeze ........................................................ DONE
#   laravel/sail .......................................................... DONE
#   laravel/tinker ........................................................ DONE
#   nesbot/carbon ......................................................... DONE
#   nunomaduro/collision .................................................. DONE
#   nunomaduro/termwind ................................................... DONE
#   spatie/laravel-ignition ............................................... DONE
#
# 100 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!

# %%
! vendor/bin/codecept build
# Out:
# Building Actor classes for suites: Acceptance
#  -> AcceptanceTesterActions.php generated successfully. 111 methods added
# TestsCodeception\AcceptanceTester includes modules: WebDriver, Db

# %%
! vendor/bin/php-cs-fixer fix --diff --dry-run .
# Out:
# PHP CS Fixer 3.54.0 15 Keys Accelerate by Fabien Potencier, Dariusz Ruminski and contributors.
# PHP runtime: 8.3.0-1ubuntu1
# Loaded config default from "/home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/./.php-cs-fixer.dist.php".
# Using cache file ".php-cs-fixer.cache".
#   0/94 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0% 19/94 [▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░]  20% 47/94 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░]  50% 57/94 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░]  60% 66/94 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░]  70% 76/94 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░]  80% 85/94 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░]  90% 94/94 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#
# Found 0 of 94 files that can be fixed in 0.394 seconds, 20.000 MB memory used

# %%
! vendor/bin/phpstan analyze -c phpstan.neon
# Out:
#   0/52 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0% 20/52 [▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░░]  38% 40/52 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░]  76% 52/52 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#  ------ ---------------------------------------------------------
#   Line   app/Http/Controllers/BookController.php
#  ------ ---------------------------------------------------------
#   63     Parameter #1 $value of function strval expects
#          bool|float|int|resource|string|null, mixed given.
#   68     Parameter #1 $value of function intval expects
#          array|bool|float|int|resource|string|null, mixed given.
#  ------ ---------------------------------------------------------
#
#
#
#  [ERROR] Found 2 errors

# %%
! ~/.composer/vendor/bin/phpcpd . --fuzzy --min-lines 1 --min-tokens 35 --exclude vendor --exclude config --exclude storage --exclude tests_codeception/Support/_generated
# Out:
# phpcpd 6.0.3 by Sebastian Bergmann.
#
# No clones found.
#
# Time: 00:00.012, Memory: 2.00 MB

# %%
! cp .env.example .env

# %%
! php artisan key:generate
# Out:
#    INFO  Application key set successfully.

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306"; do echo "Waiting for MySQL..."; sleep 1; done

# %%
! php artisan migrate:fresh
# Out:
#   Dropping all tables .......................................... 301.16ms DONE
#
#    INFO  Preparing database.
#
#   Creating migration table ...................................... 75.75ms DONE
#
#    INFO  Running migrations.
#
#   0001_01_01_000000_create_users_table ......................... 474.51ms DONE
#   0001_01_01_000001_create_cache_table ......................... 255.99ms DONE
#   0001_01_01_000002_create_jobs_table .......................... 589.73ms DONE
#   2024_05_02_133350_create_comments_table ...................... 168.87ms DONE
#   2024_05_30_110455_create_books_table .......................... 94.47ms DONE

# %%
! php artisan db:seed
# Out:
#    INFO  Seeding database.
#
#   Database\Seeders\UsersSeeder ....................................... RUNNING
#   Database\Seeders\UsersSeeder ................................... 243 ms DONE

# %%
! mysqldump -h127.0.0.1 -u root --password=root123 test > tests_codeception/Support/Data/dump.sql
# Out:
# mysqldump: [Warning] Using a password on the command line interface can be insecure.

# %%
! npm install
# Out:
# m##################) ⠦ reify:@esbuild/aix-ppc64: timing reifyNode:node_modules/
# up to date, audited 145 packages in 785ms
#
# 36 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
! npm run build
# Out:
# > build
# > vite build
#
# vite v5.2.11 building for production...
# transforming (1) resources/js/app.jstransforming (5) node_modules/axios/lib/axios.jstransforming (7) node_modules/axios/lib/utils.js✓ 48 modules transformed.
# rendering chunks (1)...rendering chunks (2)...computing gzip size (0)...computing gzip size (1)...computing gzip size (2)...computing gzip size (3)...public/build/manifest.json             0.27 kB │ gzip:  0.15 kB
# public/build/assets/app-BJFZEaIV.css  35.59 kB │ gzip:  6.80 kB
# public/build/assets/app-CrG2wnyX.js   74.00 kB │ gzip: 27.43 kB
# ✓ built in 1.38s

# %%
! php artisan test
# Out:
#    PASS  Tests\Unit\ExampleTest
#   ✓ that true is true
#
#    PASS  Tests\Feature\Auth\AuthenticationTest
#   ✓ login screen can be rendered                                         2.45s
#   ✓ users can authenticate using the login screen                        0.07s
#   ✓ users can not authenticate with invalid password                     0.25s
#   ✓ users can logout                                                     0.06s
#
#    PASS  Tests\Feature\Auth\EmailVerificationTest
#   ✓ email verification screen can be rendered                            0.05s
#   ✓ email can be verified                                                0.08s
#   ✓ email is not verified with invalid hash                              0.08s
#
#    PASS  Tests\Feature\Auth\PasswordConfirmationTest
#   ✓ confirm password screen can be rendered                              0.05s
#   ✓ password can be confirmed                                            0.10s
#   ✓ password is not confirmed with invalid password                      0.25s
#
#    PASS  Tests\Feature\Auth\PasswordResetTest
#   ✓ reset password link screen can be rendered                           0.03s
#   ✓ reset password link can be requested                                 0.12s
#   ✓ reset password screen can be rendered                                0.07s
#   ✓ password can be reset with valid token                               0.06s
#
#    PASS  Tests\Feature\Auth\PasswordUpdateTest
#   ✓ password can be updated                                              0.06s
#   ✓ correct password must be provided to update password                 0.05s
#
#    PASS  Tests\Feature\Auth\RegistrationTest
#   ✓ registration screen can be rendered                                  0.04s
#   ✓ new users can register                                               0.04s
#
#    PASS  Tests\Feature\ExampleTest
#   ✓ the application returns a successful response                        0.04s
#
#    PASS  Tests\Feature\ProfileTest
#   ✓ profile page is displayed                                            0.07s
#   ✓ profile information can be updated                                   0.06s
#   ✓ email verification status is unchanged when the email address is un… 0.05s
#   ✓ user can delete their account                                        0.06s
#   ✓ correct password must be provided to delete account                  0.05s
#
#   Tests:    25 passed (63 assertions)
#   Duration: 4.32s

# %%
import subprocess, os
os.environ["PATH"] += os.pathsep + '/opt/selenium/'
seleniumServer = subprocess.Popen(['java', '-jar', 'selenium-server-4.18.0.jar', 'standalone'], cwd='/opt/selenium/')

# %%
import subprocess
artisanServe = subprocess.Popen(['php', 'artisan', 'serve', '--port', '8888'])

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/4444"; do echo "Waiting for Selenium..."; sleep 1; done
# Out:
# 15:30:36.963 INFO [LoggingOptions.configureLogEncoding] - Using the system default encoding
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 15:30:36.971 INFO [OpenTelemetryTracer.createTracer] - Using OpenTelemetry for tracing
#
#    INFO  Server running on [http://127.0.0.1:8888].
#
#   Press Ctrl+C to stop the server
#
# 15:30:37.682 INFO [NodeOptions.getSessionFactories] - Detected 6 available processors
# 15:30:37.683 INFO [NodeOptions.discoverDrivers] - Looking for existing drivers on the PATH.
# 15:30:37.684 INFO [NodeOptions.discoverDrivers] - Add '--selenium-manager true' to the startup command to setup drivers automatically.
# 15:30:37.916 WARN [SeleniumManager.lambda$runCommand$1] - Exception managing chrome: Unable to discover proper chromedriver version in offline mode
# 15:30:37.962 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper msedgedriver version in offline mode
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 15:30:38.006 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper geckodriver version in offline mode
# 15:30:38.058 INFO [NodeOptions.report] - Adding Chrome for {"browserName": "chrome","platformName": "linux"} 6 times
# 15:30:38.075 INFO [Node.<init>] - Binding additional locator mechanisms: relative
# 15:30:38.127 INFO [GridModel.setAvailability] - Switching Node b7993a69-d025-4bf3-aa04-4d41ce2c7021 (uri: http://172.17.0.1:4444) from DOWN to UP
# 15:30:38.128 INFO [LocalDistributor.add] - Added node b7993a69-d025-4bf3-aa04-4d41ce2c7021 at http://172.17.0.1:4444. Health check every 120s
# 15:30:38.279 INFO [Standalone.execute] - Started Selenium Standalone 4.18.0 (revision b6bf9de7cc): http://172.17.0.1:4444

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/8888"; do echo "Waiting for App..."; sleep 1; done
# Out:
#   2024-05-30 15:30:39 ................................................... ~ 0s

# %%
! vendor/bin/codecept run
# Out:
# Codeception PHP Testing Framework v5.1.2 https://stand-with-ukraine.pp.ua
#
# TestsCodeception.Acceptance Tests (4) ------------------------------------------
# - Test00_HomepageCest: See Laravel links on homepage15:30:43.167 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 15:30:46.998 INFO [LocalNode.newSession] - Session created by the Node. Id: 9f6ed26f2fdd9793adbf785e7112ba39, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:44455}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 15:30:47.009 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: 9f6ed26f2fdd9793adbf785e7112ba39
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:44455}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 15:30:49.986 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "2bb2ac51b6b6ff818b01792776f2557f","eventTime": 1717075849983247665,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "POST","http.request_content_length": "35","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002furl"}}
#
# 15:30:50.048 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "737a06e88cc62796d2281c28acb05f47","eventTime": 1717075850047194165,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fscreenshot"}}
#
# 15:30:50.148 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "abca41437c0bf726e63a3e7a02ac3c4c","eventTime": 1717075850145137358,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fsource"}}
#
# 15:30:50.182 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "4de33c5e9339b2b4cb42a8fd0138f613","eventTime": 1717075850181335156,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "DELETE","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fcookie"}}
#
# E Test00_HomepageCest: See Laravel links on homepage(0.08s)
# - Test01_CommentsCest: See comments from DB displayed on page15:30:52.513 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "44565b88dd18d902c9212e7926f53cc5","eventTime": 1717075852512202607,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "POST","http.request_content_length": "43","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002furl"}}
#
# 15:30:52.535 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "2d774e5967e5c986da0f3f3f4e2d1141","eventTime": 1717075852534400752,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fscreenshot"}}
#
# 15:30:52.578 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "90c7f11e609d20dcf0e8f491c1f44958","eventTime": 1717075852577128280,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fsource"}}
#
# E Test01_CommentsCest: See comments from DB displayed on page(0.06s)
# 15:30:52.644 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "03e0be7cd65e899db8977fc159a3337c","eventTime": 1717075852642184937,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "DELETE","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fcookie"}}
#
# - Test02_LoginCest: Login with existing user15:30:54.785 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "d8d09db5190e7efbc34e3640d1f22928","eventTime": 1717075854784601392,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "POST","http.request_content_length": "44","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002furl"}}
#
# 15:30:54.801 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "4c5043c912b15548ee943df4f161f124","eventTime": 1717075854801000655,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fscreenshot"}}
#
# 15:30:54.901 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "0eb222ad7357227da6358ebd27a1fe77","eventTime": 1717075854886054189,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fsource"}}
#
# E Test02_LoginCest: Login with existing user(0.02s)
# 15:30:54.921 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "c775062b5e4bea69604aca3738995d7e","eventTime": 1717075854919756653,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "DELETE","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fcookie"}}
#
# - Test03_BooksCest: Have books page15:30:57.734 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "9b7703e532b666754504fef019b81654","eventTime": 1717075857727667470,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "POST","http.request_content_length": "40","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002furl"}}
#
# 15:30:57.780 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "4e9e654781f182c566ef62232da4435b","eventTime": 1717075857780016535,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fscreenshot"}}
#
# 15:30:57.802 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "f4bdd139774f80e2d5497b800d6726a1","eventTime": 1717075857799695836,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fsource"}}
#
# E Test03_BooksCest: Have books page(0.03s)
# 15:30:57.852 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "66cbc9ec355e3645cdd5c828f84074cf","eventTime": 1717075857851145847,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "DELETE","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002f9f6ed26f2fdd9793adbf785e7112ba39\u002fcookie"}}
#
# 15:30:57.929 INFO [LocalSessionMap.lambda$new$0] - Deleted session from local Session Map, Id: 9f6ed26f2fdd9793adbf785e7112ba39
# 15:30:57.931 INFO [GridModel.release] - Releasing slot for session id 9f6ed26f2fdd9793adbf785e7112ba39
# 15:30:57.934 INFO [SessionSlot.stop] - Stopping session 9f6ed26f2fdd9793adbf785e7112ba39
# --------------------------------------------------------------------------------
# Time: 00:17.699, Memory: 14.00 MB
#
# There were 4 errors:
# 1) Test00_HomepageCest: See Laravel links on homepage
#  Test  tests_codeception/Acceptance/Test00_HomepageCest.php:test
#
#   [Facebook\WebDriver\Exception\NoSuchWindowException] no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=121.0.6167.184)
#
#
# Scenario Steps:
#
#  1. $I->amOnPage("/") at tests_codeception/Acceptance/Test00_HomepageCest.php:13
#
# #1  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Exception/WebDriverException.php:124
# #2  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/HttpCommandExecutor.php:359
# #3  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:601
# #4  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:260
# #5  Codeception\Module\WebDriver->amOnPage
# #6  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/Support/_generated/AcceptanceTesterActions.php:585
# #7  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/Acceptance/Test00_HomepageCest.php:13
# #8  TestsCodeception\Acceptance\Test00_HomepageCest->test
# #9  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/bin/codecept:119
# Artifacts:
#
# Png: /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.png
# Html: /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.html
# 2) Test01_CommentsCest: See comments from DB displayed on page
#  Test  tests_codeception/Acceptance/Test01_CommentsCest.php:test
#
#   [Facebook\WebDriver\Exception\NoSuchWindowException] no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=121.0.6167.184)
#
#
# Scenario Steps:
#
#  3. $I->amOnPage("/comments") at tests_codeception/Acceptance/Test01_CommentsCest.php:22
#  2. $I->haveInDatabase("comments",{"title":"Title 1401438293","text":"Some ...}) at tests_codeception/Acceptance/Test01_CommentsCest.php:20
#  1. $I->seeNumRecords(0,"comments") at tests_codeception/Acceptance/Test01_CommentsCest.php:13
#
# #1  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Exception/WebDriverException.php:124
# #2  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/HttpCommandExecutor.php:359
# #3  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:601
# #4  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:260
# #5  Codeception\Module\WebDriver->amOnPage
# #6  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/Support/_generated/AcceptanceTesterActions.php:585
# #7  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/Acceptance/Test01_CommentsCest.php:22
# #8  TestsCodeception\Acceptance\Test01_CommentsCest->test
# #9  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/bin/codecept:119
# Artifacts:
#
# Png: /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test01.CommentsCest.test.fail.png
# Html: /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test01.CommentsCest.test.fail.html
# 3) Test02_LoginCest: Login with existing user
#  Test  tests_codeception/Acceptance/Test02_LoginCest.php:test
#
#   [Facebook\WebDriver\Exception\NoSuchWindowException] no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=121.0.6167.184)
#
#
# Scenario Steps:
#
#  1. $I->amOnPage("/dashboard") at tests_codeception/Acceptance/Test02_LoginCest.php:13
#
# #1  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Exception/WebDriverException.php:124
# #2  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/HttpCommandExecutor.php:359
# #3  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:601
# #4  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:260
# #5  Codeception\Module\WebDriver->amOnPage
# #6  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/Support/_generated/AcceptanceTesterActions.php:585
# #7  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/Acceptance/Test02_LoginCest.php:13
# #8  TestsCodeception\Acceptance\Test02_LoginCest->test
# #9  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/bin/codecept:119
# Artifacts:
#
# Png: /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.png
# Html: /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.html
# 4) Test03_BooksCest: Have books page
#  Test  tests_codeception/Acceptance/Test03_BooksCest.php:test
#
#   [Facebook\WebDriver\Exception\NoSuchWindowException] no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=121.0.6167.184)
#
#
# Scenario Steps:
#
#  1. $I->amOnPage("/books") at tests_codeception/Acceptance/Test03_BooksCest.php:13
#
# #1  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Exception/WebDriverException.php:124
# #2  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/HttpCommandExecutor.php:359
# #3  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:601
# #4  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:260
# #5  Codeception\Module\WebDriver->amOnPage
# #6  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/Support/_generated/AcceptanceTesterActions.php:585
# #7  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/Acceptance/Test03_BooksCest.php:13
# #8  TestsCodeception\Acceptance\Test03_BooksCest->test
# #9  /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/vendor/bin/codecept:119
# Artifacts:
#
# Png: /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.png
# Html: /home/student/php_2024_piotr_powroznik/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.html
#
# ERRORS!
# Tests: 4, Assertions: 1, Errors: 4.

# %% [markdown]
# Edit the code:

# %%
! phpstorm .
# Out:
# CompileCommand: exclude com/intellij/openapi/vfs/impl/FilePartNodeRoot.trieDescend bool exclude = true
# 2024-05-30 15:31:01,260 [   1694]   WARN - #c.i.s.ComponentManagerImpl - `preload=true` must be used only for core services (service=com.intellij.ae.database.core.baseEvents.fus.AddStatisticsEventLogListenerTemporary, plugin=com.jetbrains.ae.database)
# 2024-05-30 15:31:01,261 [   1695]   WARN - #c.i.s.ComponentManagerImpl - `preload=true` must be used only for core services (service=com.jetbrains.rdserver.statistics.BackendStatisticsManager, plugin=com.jetbrains.codeWithMe)
# 2024-05-30 15:31:02,905 [   3339]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.search.FilenameIndex initializer requests com.intellij.ide.plugins.PluginUtil instance
# 2024-05-30 15:31:04,163 [   4597]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.lang.javascript.psi.jsdoc.impl.JSDocCustomTags initializer requests com.intellij.lang.javascript.JSDisposable instance
# 2024-05-30 15:31:05,010 [   5444]   WARN - #c.i.o.v.n.p.d.e.DurableEnumeratorFactory - [enumerator.mmapped]: .valueToId map is out-of-sync with .valuesLog data -> rebuilding it
# 2024-05-30 15:31:05,362 [   5796]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.LanguageSubstitutors initializer requests com.intellij.psi.LanguageSubstitutors instance
# 2024-05-30 15:31:05,410 [   5844]   WARN - #c.i.s.ComponentManagerImpl - org.zmlx.hg4idea.provider.HgChangeProvider initializer requests com.intellij.openapi.vcs.FileStatusFactory instance
# 2024-05-30 15:31:07,010 [   7444]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.codeStyle.CodeStyleSettingsCustomizable initializer requests com.intellij.util.LocaleSensitiveApplicationCacheService instance
# 2024-05-30 15:31:08,057 [   8491]   WARN - #o.j.p.t.TextMateService - Cannot find referenced file `./language-configuration.json` in bundle `/opt/PhpStorm-233.14475.35/plugins/textmate/lib/bundles/mdx`
# 2024-05-30 15:31:08,313 [   8747]   WARN - #c.i.u.x.Binding - no accessors for com.jetbrains.php.testFramework.PhpTestFrameworkType
# 2024-05-30 15:31:09,149 [   9583]   WARN - #c.i.o.a.i.ActionUpdater - 690 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-05-30 15:31:09,368 [   9802]   WARN - #c.i.o.a.i.ActionUpdater - 375 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-05-30 15:31:12,546 [  12980]   WARN - #c.i.o.a.i.ActionUpdater - 833 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-05-30 15:31:12,546 [  12980]   WARN - #c.i.o.a.i.ActionUpdater - 833 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-05-30 15:31:13,688 [  14122]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.UndispatchedCoroutine.afterResume(CoroutineContext.kt:270)
# 	at kotlinx.coroutines.AbstractCoroutine.resumeWith(AbstractCoroutine.kt:102)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:46)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-05-30 15:31:13,698 [  14132]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.UndispatchedCoroutine.afterResume(CoroutineContext.kt:270)
# 	at kotlinx.coroutines.AbstractCoroutine.resumeWith(AbstractCoroutine.kt:102)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:46)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-05-30 15:31:14,429 [  14863]   WARN - #c.i.i.s.p.i.BundledSharedIndexPostStartupActivity - Skipped 1 pre-built shared indexes: bundled-js-predefined-1d06a55b98c1-985749b364ce-JavaScript-PS-233.14475.35
# 2024-05-30 15:31:14,901 [  15335]   WARN - org.eclipse.lsp4j.jsonrpc.services.GenericEndpoint - Unsupported notification method: @/tailwindCSS/projectInitialized
# 2024-05-30 15:31:15,299 [  15733]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.database.console.session.DatabaseSessionManager initializer requests com.intellij.database.console.session.DatabaseSessionViewService instance
# 2024-05-30 15:31:15,786 [  16220]   WARN - #c.i.o.a.i.ActionUpdater - 1112 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-05-30 15:31:15,786 [  16220]   WARN - #c.i.o.a.i.ActionUpdater - 1111 ms to grab EDT for FontEditorPreview$RestorePreviewTextAction#Update@ContextToolbar (com.intellij.application.options.colors.FontEditorPreview$RestorePreviewTextAction)
# 2024-05-30 15:31:15,787 [  16221]   WARN - #c.i.o.a.i.ActionUpdater - 1111 ms to grab EDT for FontEditorPreview$ToggleBoldFontAction#Update@ContextToolbar (com.intellij.application.options.colors.FontEditorPreview$ToggleBoldFontAction)
# 2024-05-30 15:31:15,789 [  16223]   WARN - #c.i.o.a.i.ActionUpdater - 1110 ms to grab EDT for EditorMarkupModelImpl$TrafficLightAction#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$TrafficLightAction)
# 2024-05-30 15:31:15,790 [  16224]   WARN - #c.i.o.a.i.ActionUpdater - 1113 ms to grab EDT for EditorMarkupModelImpl$1#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$1)
# 2024-05-30 15:31:15,793 [  16227]   WARN - #c.i.o.a.i.ActionUpdater - 1113 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-05-30 15:31:15,860 [  16294]   WARN - #c.i.o.a.i.ActionUpdater - 1181 ms to grab EDT for ReviewModeActionGroup#Update@EditorInspectionsToolbar (org.jetbrains.plugins.gitlab.mergerequest.ui.editor.action.ReviewModeActionGroup)
# 2024-05-30 15:31:16,275 [  16709]   WARN - #c.i.o.a.i.ActionUpdater - 3406 ms total to grab EDT 3 times to expand DefaultActionGroup@EditorInspectionsToolbar (com.intellij.openapi.actionSystem.DefaultActionGroup). Use `ActionUpdateThread.BGT`.
# 2024-05-30 15:31:16,832 [  17266]   WARN - #c.i.o.a.i.ActionUpdater - 382 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-05-30 15:31:16,833 [  17267]   WARN - #c.i.o.a.i.ActionUpdater - 316 ms to grab EDT for FontEditorPreview$RestorePreviewTextAction#Update@ContextToolbar (com.intellij.application.options.colors.FontEditorPreview$RestorePreviewTextAction)
# 2024-05-30 15:31:16,833 [  17267]   WARN - #c.i.o.a.i.ActionUpdater - 316 ms to grab EDT for FontEditorPreview$ToggleBoldFontAction#Update@ContextToolbar (com.intellij.application.options.colors.FontEditorPreview$ToggleBoldFontAction)
# 2024-05-30 15:31:16,835 [  17269]   WARN - #c.i.o.a.i.ActionUpdater - 317 ms to grab EDT for EditorMarkupModelImpl$TrafficLightAction#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$TrafficLightAction)
# 2024-05-30 15:31:16,885 [  17319]   WARN - #c.i.o.a.i.ActionUpdater - 367 ms to grab EDT for EditorMarkupModelImpl$1#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$1)
# 2024-05-30 15:31:16,888 [  17322]   WARN - #c.i.o.a.i.ActionUpdater - 364 ms to grab EDT for ReviewModeActionGroup#Update@EditorInspectionsToolbar (org.jetbrains.plugins.gitlab.mergerequest.ui.editor.action.ReviewModeActionGroup)
# 2024-05-30 15:31:16,889 [  17323]   WARN - #c.i.o.a.i.ActionUpdater - 365 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-05-30 15:31:19,892 [  20326]   WARN - #c.i.o.a.i.ActionUpdater - 350 ms to grab EDT for DockToolWindowAction#Update@ToolwindowTitle (com.intellij.openapi.wm.impl.DockToolWindowAction)
# 2024-05-30 15:31:19,893 [  20327]   WARN - #c.i.o.a.i.ActionUpdater - 347 ms to grab EDT for ExpandAllAction#Update@ToolwindowTitle (com.intellij.ide.actions.ExpandAllAction)
# 2024-05-30 15:31:19,894 [  20328]   WARN - #c.i.o.a.i.ActionUpdater - 348 ms to grab EDT for CollapseAllAction#Update@ToolwindowTitle (com.intellij.ide.actions.CollapseAllAction)
# 2024-05-30 15:31:20,938 [  21372]   WARN - #c.i.o.a.i.ActionUpdater - 386 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-05-30 15:31:24,840 [  25274]   WARN - #c.j.p.PhpIndex - Completing type '#M#g#F\App\Http\Controllers\view.with' took 3648ms, visited:[#π(#M#g#F\App\Http\Controllers\view.with)("books")(#M#C\App\Models\Book.all), #M#π(#g#F\App\Http\Controllers\view)("books.index").with, #M#g#F\App\Http\Controllers\view.with, #π(#M#π(#g#F\App\Http\Controllers\view)("books.index").with)("books")(#M#C\App\Models\Book.all)]
# 2024-05-30 15:31:28,463 [  28897]   WARN - org.eclipse.lsp4j.jsonrpc.services.GenericEndpoint - Unsupported notification method: @/tailwindCSS/projectInitialized
# 2024-05-30 15:31:32,145 [  32579]   WARN - #c.j.p.PhpIndex - Completing type '#F\App\Http\Controllers\view' took 1888ms, visited:[#F\App\Http\Controllers\view]
# 2024-05-30 15:32:00,632 [  61066]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable<#ᢐ\TRescueValue.>'
# 2024-05-30 15:32:00,633 [  61067]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable<>'
# 2024-05-30 15:32:01,112 [  61546]   WARN - #c.i.u.x.Binding - no accessors for com.intellij.ide.util.TipsUsageManager$State
# 2024-05-30 15:33:52,892 [ 173326]   WARN - #c.i.o.v.n.p.FSRecords - Attribute FileAttribute[PhpExtensionStubsMetadataProvider]{version: 2, fixedSize: false, shouldEnumerate: false} value is quite large: 122089 b > warn threshold(102400) -> please, do not use VFS file attributes for huge blobs of data. Consider using GistManager or GistStorage.
# 2024-05-30 15:40:18,113 [ 558547]   WARN - #c.i.o.a.i.ActionUpdater - 373 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-05-30 15:40:18,123 [ 558557]   WARN - #c.i.o.a.i.ActionUpdater - 382 ms to grab EDT for EditorMarkupModelImpl$1#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$1)
# 2024-05-30 15:40:18,123 [ 558557]   WARN - #c.i.o.a.i.ActionUpdater - 382 ms to grab EDT for FontEditorPreview$RestorePreviewTextAction#Update@ContextToolbar (com.intellij.application.options.colors.FontEditorPreview$RestorePreviewTextAction)
# 2024-05-30 15:40:18,122 [ 558556]   WARN - #c.i.o.a.i.ActionUpdater - 382 ms to grab EDT for EditorMarkupModelImpl$TrafficLightAction#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$TrafficLightAction)
# 2024-05-30 15:40:18,123 [ 558557]   WARN - #c.i.o.a.i.ActionUpdater - 382 ms to grab EDT for FontEditorPreview$ToggleBoldFontAction#Update@ContextToolbar (com.intellij.application.options.colors.FontEditorPreview$ToggleBoldFontAction)
# 2024-05-30 15:40:18,133 [ 558567]   WARN - #c.i.o.a.i.ActionUpdater - 382 ms to grab EDT for ReviewModeActionGroup#Update@EditorInspectionsToolbar (org.jetbrains.plugins.gitlab.mergerequest.ui.editor.action.ReviewModeActionGroup)
# 15:40:20.325 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 15:40:22.325 INFO [LocalNode.newSession] - Session created by the Node. Id: b777b3802af4300e8a96057782162818, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:46377}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 15:40:22.346 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: b777b3802af4300e8a96057782162818
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:46377}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
#   2024-05-30 15:40:25 .................................................. ~ -1s
#   2024-05-30 15:40:26 /favicon.ico ..................................... ~ -1s
#   2024-05-30 15:40:30 ................................................... ~ 0s
#   2024-05-30 15:40:30 /build/assets/app-BJFZEaIV.css ................... ~ -1s
#   2024-05-30 15:40:31 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:40:31 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:40:38 ................................................... ~ 0s
#   2024-05-30 15:40:38 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:40:38 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:40:38 /favicon.ico ...................................... ~ 0s
# 15:40:48.139 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 15:40:50.165 INFO [LocalNode.newSession] - Session created by the Node. Id: 7f4b8093a78a0cdccb4975720e64d9c7, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:46625}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 15:40:50.172 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: 7f4b8093a78a0cdccb4975720e64d9c7
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:46625}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
#   2024-05-30 15:40:55 ................................................... ~ 0s
#   2024-05-30 15:40:55 ................................................... ~ 0s
#   2024-05-30 15:40:55 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:40:55 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:40:55 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:40:57 .................................................. ~ -1s
#   2024-05-30 15:40:58 ................................................... ~ 0s
#   2024-05-30 15:40:58 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:40:58 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
# 2024-05-30 15:40:59,787 [ 600221]   WARN - #c.i.o.a.i.ActionUpdater - 324 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
#   2024-05-30 15:40:59 /favicon.ico ...................................... ~ 0s
# 2024-05-30 15:41:02,850 [ 603284]   WARN - #c.i.o.a.i.ActionUpdater - 317 ms to grab EDT for EditorMarkupModelImpl$TrafficLightAction#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$TrafficLightAction)
# 2024-05-30 15:41:02,856 [ 603290]   WARN - #c.i.o.a.i.ActionUpdater - 316 ms to grab EDT for FakeRerunAction#Update@RunnerToolbar (com.intellij.execution.runners.FakeRerunAction)
# 2024-05-30 15:41:02,857 [ 603291]   WARN - #c.i.o.a.i.ActionUpdater - 316 ms to grab EDT for ToggleAutoTestAction#Update@RunnerToolbar (com.intellij.execution.testframework.autotest.ToggleAutoTestAction)
# 2024-05-30 15:41:02,857 [ 603291]   WARN - #c.i.o.a.i.ActionUpdater - 316 ms to grab EDT for DumbAwareToggleInvertedBooleanProperty#Update@RunnerToolbar (com.intellij.util.config.DumbAwareToggleInvertedBooleanProperty)
# 2024-05-30 15:41:02,859 [ 603293]   WARN - #c.i.o.a.i.ActionUpdater - 316 ms to grab EDT for DumbAwareToggleInvertedBooleanProperty#Update@RunnerToolbar (com.intellij.util.config.DumbAwareToggleInvertedBooleanProperty)
# 2024-05-30 15:41:02,855 [ 603289]   WARN - #c.i.o.a.i.ActionUpdater - 317 ms to grab EDT for EditorMarkupModelImpl$1#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$1)
# 2024-05-30 15:41:02,860 [ 603294]   WARN - #c.i.o.a.i.ActionUpdater - 316 ms to grab EDT for DumbAwareToggleBooleanProperty#Update@RunnerToolbar (com.intellij.util.config.DumbAwareToggleBooleanProperty)
# 2024-05-30 15:41:02,925 [ 603359]   WARN - #c.i.o.a.i.ActionUpdater - 327 ms to grab EDT for ExpandAllAction#Update@RunnerToolbar (com.intellij.ide.actions.ExpandAllAction)
# 2024-05-30 15:41:02,953 [ 603387]   WARN - #c.i.o.a.i.ActionUpdater - 328 ms to grab EDT for TrackCoverageAction#Update@RunnerToolbar (com.intellij.coverage.actions.TrackCoverageAction)
# 2024-05-30 15:41:02,968 [ 603402]   WARN - #c.i.o.a.i.ActionUpdater - 358 ms to grab EDT for ReviewModeActionGroup#Update@EditorInspectionsToolbar (org.jetbrains.plugins.gitlab.mergerequest.ui.editor.action.ReviewModeActionGroup)
# 2024-05-30 15:41:03,005 [ 603439]   WARN - #c.i.o.a.i.ActionUpdater - 378 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-05-30 15:41:04,082 [ 604516]   WARN - #c.i.o.a.i.ActionUpdater - 331 ms to grab EDT for NextOccurenceToolbarAction#getNavigator@TestRunnerResults (com.intellij.ide.actions.NextOccurenceToolbarAction)
# 2024-05-30 15:41:04,090 [ 604524]   WARN - #c.i.o.a.i.ActionUpdater - 332 ms to grab EDT for PreviousOccurenceToolbarAction#getNavigator@TestRunnerResults (com.intellij.ide.actions.PreviousOccurenceToolbarAction)
#   2024-05-30 15:41:06 .................................................. ~ -1s
#   2024-05-30 15:41:07 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:41:07 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:41:08 /favicon.ico ...................................... ~ 0s
# 2024-05-30 15:41:09,690 [ 610124]   WARN - #c.i.o.a.i.ActionUpdater - 412 ms to grab EDT for ExpandAllAction#Update@ToolwindowTitle (com.intellij.ide.actions.ExpandAllAction)
#   2024-05-30 15:41:12 .................................................. ~ -1s
#   2024-05-30 15:41:13 ................................................... ~ 0s
#   2024-05-30 15:41:13 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:41:13 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:41:13 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:41:14 ................................................... ~ 0s
#   2024-05-30 15:41:14 .................................................. ~ -1s
#   2024-05-30 15:41:15 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:41:15 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:41:15 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:41:16 ................................................... ~ 0s
#   2024-05-30 15:41:16 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:41:16 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:41:16 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:41:17 ................................................... ~ 0s
#   2024-05-30 15:41:17 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:41:17 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:41:17 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:41:18 ................................................... ~ 0s
#   2024-05-30 15:41:18 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:41:18 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:41:18 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:41:21 ................................................... ~ 0s
#   2024-05-30 15:41:21 ................................................... ~ 0s
#   2024-05-30 15:41:21 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:41:21 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:41:21 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:41:22 ................................................... ~ 0s
#   2024-05-30 15:41:22 /favicon.ico ..................................... ~ -1s
# 15:41:44.277 INFO [LocalSessionMap.lambda$new$0] - Deleted session from local Session Map, Id: 7f4b8093a78a0cdccb4975720e64d9c7
# 15:41:44.278 INFO [GridModel.release] - Releasing slot for session id 7f4b8093a78a0cdccb4975720e64d9c7
# 15:41:44.280 INFO [SessionSlot.stop] - Stopping session 7f4b8093a78a0cdccb4975720e64d9c7
# 15:41:49.134 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 15:41:52.640 INFO [LocalNode.newSession] - Session created by the Node. Id: 8b5fdda3c3a71bd3137eeb561c4bca4e, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:45663}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 15:41:52.842 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: 8b5fdda3c3a71bd3137eeb561c4bca4e
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:45663}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
#   2024-05-30 15:41:56 ................................................... ~ 0s
#   2024-05-30 15:41:56 ................................................... ~ 0s
#   2024-05-30 15:41:56 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:41:56 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:41:57 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:41:58 ................................................... ~ 0s
#   2024-05-30 15:41:58 ................................................... ~ 0s
#   2024-05-30 15:41:58 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:41:58 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:41:59 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:42:04 .................................................. ~ -1s
#   2024-05-30 15:42:05 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:42:05 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:42:06 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:42:10 ................................................... ~ 0s
#   2024-05-30 15:42:10 .................................................. ~ -1s
#   2024-05-30 15:42:11 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:42:11 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:42:11 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:42:12 ................................................... ~ 0s
#   2024-05-30 15:42:12 ................................................... ~ 0s
#   2024-05-30 15:42:12 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:42:12 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:42:12 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:42:13 ................................................... ~ 0s
#   2024-05-30 15:42:13 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:42:13 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:42:14 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:42:15 ................................................... ~ 0s
#   2024-05-30 15:42:15 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:42:15 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:42:15 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:42:15 .................................................. ~ -1s
#   2024-05-30 15:42:16 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:42:16 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:42:16 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:42:19 ................................................... ~ 0s
#   2024-05-30 15:42:19 ................................................... ~ 0s
#   2024-05-30 15:42:19 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:42:19 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:42:19 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:42:20 ................................................... ~ 0s
#   2024-05-30 15:42:20 ................................................... ~ 0s
#   2024-05-30 15:42:20 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:42:20 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:42:21 /favicon.ico ...................................... ~ 0s
# 15:42:41.749 INFO [LocalSessionMap.lambda$new$0] - Deleted session from local Session Map, Id: 8b5fdda3c3a71bd3137eeb561c4bca4e
# 15:42:41.749 INFO [GridModel.release] - Releasing slot for session id 8b5fdda3c3a71bd3137eeb561c4bca4e
# 15:42:41.751 INFO [SessionSlot.stop] - Stopping session 8b5fdda3c3a71bd3137eeb561c4bca4e
# 15:44:50.344 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 15:44:52.373 INFO [LocalNode.newSession] - Session created by the Node. Id: e9843a5398c39a7e9b86d420049db0c3, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:33489}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 15:44:52.381 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: e9843a5398c39a7e9b86d420049db0c3
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:33489}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 2024-05-30 15:44:54,478 [ 834912]   WARN - #c.i.o.a.i.ActionUpdater - 312 ms to grab EDT for FontEditorPreview$RestorePreviewTextAction#Update@ContextToolbar (com.intellij.application.options.colors.FontEditorPreview$RestorePreviewTextAction)
# 2024-05-30 15:44:54,923 [ 835357]   WARN - #c.i.o.a.i.ActionUpdater - 310 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
#   2024-05-30 15:44:57 ................................................... ~ 0s
#   2024-05-30 15:44:57 ................................................... ~ 0s
#   2024-05-30 15:44:57 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:44:57 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:44:57 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:44:58 ................................................... ~ 0s
#   2024-05-30 15:44:58 ................................................... ~ 0s
#   2024-05-30 15:44:59 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:44:59 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:44:59 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:44:59 ................................................... ~ 0s
#   2024-05-30 15:44:59 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:44:59 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:44:59 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:45:05 .................................................. ~ -1s
#   2024-05-30 15:45:06 ................................................... ~ 0s
#   2024-05-30 15:45:06 /build/assets/app-BJFZEaIV.css ................... ~ -1s
#   2024-05-30 15:45:06 /build/assets/app-CrG2wnyX.js .................... ~ -1s
#   2024-05-30 15:45:07 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:45:10 ................................................... ~ 0s
#   2024-05-30 15:45:10 ................................................... ~ 0s
#   2024-05-30 15:45:10 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:45:10 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:45:10 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:45:11 ................................................... ~ 0s
#   2024-05-30 15:45:11 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:45:11 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:45:11 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:45:12 ................................................... ~ 0s
#   2024-05-30 15:45:12 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:45:12 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:45:12 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:45:13 ................................................... ~ 0s
#   2024-05-30 15:45:13 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:45:13 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:45:13 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:45:15 ................................................... ~ 0s
#   2024-05-30 15:45:15 .................................................. ~ -1s
#   2024-05-30 15:45:16 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:45:16 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:45:16 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:45:16 ................................................... ~ 0s
#   2024-05-30 15:45:16 .................................................. ~ -1s
#   2024-05-30 15:45:17 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:45:17 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:45:17 /favicon.ico ...................................... ~ 0s
# 2024-05-30 15:45:26,449 [ 866883]   WARN - #c.i.u.i.CachedImageIcon - Cannot get reflective icon (path=icons.PhpIcons.Trait)
# java.lang.ClassNotFoundException: icons.PhpIcons
# 	at com.intellij.util.lang.UrlClassLoader.findClass(UrlClassLoader.java:246)
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:592)
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:525)
# 	at com.intellij.ui.icons.ImageDataByPathLoaderKt.getReflectiveIcon(ImageDataByPathLoader.kt:169)
# 	at com.intellij.openapi.util.IconLoaderKt.findIconUsingDeprecatedImplementation(IconLoader.kt:369)
# 	at com.intellij.openapi.util.IconLoaderKt.findIconUsingDeprecatedImplementation$default(IconLoader.kt:354)
# 	at com.intellij.openapi.util.IconLoader.findIcon(IconLoader.kt:147)
# 	at com.intellij.util.ui.ExtendableHTMLViewFactory$Extensions$IconsExtension.getIcon(ExtendableHTMLViewFactory.kt:143)
# 	at com.intellij.util.ui.ExtendableHTMLViewFactory$Extensions$IconsExtension.invoke(ExtendableHTMLViewFactory.kt:134)
# 	at com.intellij.util.ui.ExtendableHTMLViewFactory$Extensions$IconsExtension.invoke(ExtendableHTMLViewFactory.kt:127)
# 	at com.intellij.util.ui.ExtendableHTMLViewFactory.create(ExtendableHTMLViewFactory.kt:41)
# 	at java.desktop/javax.swing.text.CompositeView.loadChildren(CompositeView.java:112)
# 	at java.desktop/javax.swing.text.FlowView$LogicalView.loadChildren(FlowView.java:731)
# 	at java.desktop/javax.swing.text.CompositeView.setParent(CompositeView.java:139)
# 	at java.desktop/javax.swing.text.FlowView.loadChildren(FlowView.java:147)
# 	at java.desktop/javax.swing.text.CompositeView.setParent(CompositeView.java:139)
# 	at java.desktop/javax.swing.text.FlowView.setParent(FlowView.java:306)
# 	at java.desktop/javax.swing.text.html.ParagraphView.setParent(ParagraphView.java:75)
# 	at java.desktop/javax.swing.text.CompositeView.replace(CompositeView.java:219)
# 	at java.desktop/javax.swing.text.BoxView.replace(BoxView.java:182)
# 	at java.desktop/javax.swing.text.CompositeView.loadChildren(CompositeView.java:114)
# 	at java.desktop/javax.swing.text.CompositeView.setParent(CompositeView.java:139)
# 	at java.desktop/javax.swing.text.html.BlockView.setParent(BlockView.java:72)
# 	at java.desktop/javax.swing.text.CompositeView.replace(CompositeView.java:219)
# 	at java.desktop/javax.swing.text.BoxView.replace(BoxView.java:182)
# 	at java.desktop/javax.swing.text.CompositeView.loadChildren(CompositeView.java:114)
# 	at java.desktop/javax.swing.text.CompositeView.setParent(CompositeView.java:139)
# 	at java.desktop/javax.swing.text.html.BlockView.setParent(BlockView.java:72)
# 	at java.desktop/javax.swing.text.html.HTMLEditorKit$HTMLFactory$BodyBlockView.setParent(HTMLEditorKit.java:1476)
# 	at java.desktop/javax.swing.text.CompositeView.replace(CompositeView.java:219)
# 	at java.desktop/javax.swing.text.BoxView.replace(BoxView.java:182)
# 	at java.desktop/javax.swing.text.View.updateChildren(View.java:1129)
# 	at java.desktop/javax.swing.text.View.insertUpdate(View.java:708)
# 	at java.desktop/javax.swing.plaf.basic.BasicTextUI$RootView.insertUpdate(BasicTextUI.java:1714)
# 	at java.desktop/javax.swing.plaf.basic.BasicTextUI$UpdateHandler.insertUpdate(BasicTextUI.java:1996)
# 	at java.desktop/javax.swing.text.AbstractDocument.fireInsertUpdate(AbstractDocument.java:226)
# 	at java.desktop/javax.swing.text.DefaultStyledDocument.create(DefaultStyledDocument.java:160)
# 	at java.desktop/javax.swing.text.html.HTMLDocument.create(HTMLDocument.java:472)
# 	at java.desktop/javax.swing.text.html.HTMLDocument$HTMLReader.flushBuffer(HTMLDocument.java:4033)
# 	at java.desktop/javax.swing.text.html.HTMLDocument$HTMLReader.addContent(HTMLDocument.java:3972)
# 	at java.desktop/javax.swing.text.html.HTMLDocument$HTMLReader.addContent(HTMLDocument.java:3937)
# 	at java.desktop/javax.swing.text.html.HTMLDocument$HTMLReader.handleText(HTMLDocument.java:2797)
# 	at java.desktop/javax.swing.text.html.parser.DocumentParser.handleText(DocumentParser.java:271)
# 	at java.desktop/javax.swing.text.html.parser.Parser.handleText(Parser.java:409)
# 	at java.desktop/javax.swing.text.html.parser.Parser.endTag(Parser.java:524)
# 	at java.desktop/javax.swing.text.html.parser.Parser.parseTag(Parser.java:1931)
# 	at java.desktop/javax.swing.text.html.parser.Parser.parseContent(Parser.java:2195)
# 	at java.desktop/javax.swing.text.html.parser.Parser.parse(Parser.java:2372)
# 	at java.desktop/javax.swing.text.html.parser.DocumentParser.parse(DocumentParser.java:135)
# 	at java.desktop/javax.swing.text.html.parser.ParserDelegator.parse(ParserDelegator.java:114)
# 	at java.desktop/javax.swing.text.html.HTMLEditorKit.read(HTMLEditorKit.java:264)
# 	at java.desktop/javax.swing.JEditorPane.setText(JEditorPane.java:1484)
# 	at com.intellij.codeInsight.documentation.DocumentationEditorPane.setText(DocumentationEditorPane.java:101)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.updateContent(DocumentationUI.kt:226)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.handleContent(DocumentationUI.kt:175)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.handleContent(DocumentationUI.kt:164)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.access$handleContent(DocumentationUI.kt:47)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$handlePage$2.invokeSuspend(DocumentationUI.kt:144)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$handlePage$2.invoke(DocumentationUI.kt)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$handlePage$2.invoke(DocumentationUI.kt)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2$firstJob$1.invokeSuspend(flow.kt:68)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2$firstJob$1.invoke(flow.kt)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2$firstJob$1.invoke(flow.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startCoroutineUndispatched(Undispatched.kt:44)
# 	at kotlinx.coroutines.CoroutineStart.invoke(CoroutineStart.kt:112)
# 	at kotlinx.coroutines.AbstractCoroutine.start(AbstractCoroutine.kt:126)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch(Builders.common.kt:56)
# 	at kotlinx.coroutines.BuildersKt.launch(Unknown Source)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch$default(Builders.common.kt:47)
# 	at kotlinx.coroutines.BuildersKt.launch$default(Unknown Source)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2.invokeSuspend(flow.kt:67)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2.invoke(flow.kt)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2.invoke(flow.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:264)
# 	at com.intellij.util.flow.FlowKt.collectLatestUndispatched(flow.kt:66)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.handlePage(DocumentationUI.kt:143)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.access$handlePage(DocumentationUI.kt:47)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6$1.invokeSuspend(DocumentationUI.kt:99)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6$1.invoke(DocumentationUI.kt)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6$1.invoke(DocumentationUI.kt)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2$firstJob$1.invokeSuspend(flow.kt:68)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2$firstJob$1.invoke(flow.kt)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2$firstJob$1.invoke(flow.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startCoroutineUndispatched(Undispatched.kt:44)
# 	at kotlinx.coroutines.CoroutineStart.invoke(CoroutineStart.kt:112)
# 	at kotlinx.coroutines.AbstractCoroutine.start(AbstractCoroutine.kt:126)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch(Builders.common.kt:56)
# 	at kotlinx.coroutines.BuildersKt.launch(Unknown Source)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch$default(Builders.common.kt:47)
# 	at kotlinx.coroutines.BuildersKt.launch$default(Unknown Source)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2.invokeSuspend(flow.kt:67)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2.invoke(flow.kt)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2.invoke(flow.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:264)
# 	at com.intellij.util.flow.FlowKt.collectLatestUndispatched(flow.kt:66)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6.invokeSuspend(DocumentationUI.kt:98)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6.invoke(DocumentationUI.kt)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6.invoke(DocumentationUI.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startCoroutineUndispatched(Undispatched.kt:44)
# 	at kotlinx.coroutines.CoroutineStart.invoke(CoroutineStart.kt:112)
# 	at kotlinx.coroutines.AbstractCoroutine.start(AbstractCoroutine.kt:126)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch(Builders.common.kt:56)
# 	at kotlinx.coroutines.BuildersKt.launch(Unknown Source)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.<init>(DocumentationUI.kt:97)
# 	at com.intellij.lang.documentation.ide.impl.DocumentationTargetHoverInfo.createQuickDocComponent(DocumentationTargetHoverInfo.kt:103)
# 	at com.intellij.openapi.editor.EditorHoverInfo.createComponent(EditorHoverInfo.java:31)
# 	at com.intellij.openapi.editor.EditorMouseHoverPopupManager.lambda$scheduleProcessing$3(EditorMouseHoverPopupManager.java:183)
# 	at com.intellij.openapi.application.TransactionGuardImpl.runWithWritingAllowed(TransactionGuardImpl.java:209)
# 	at com.intellij.openapi.application.TransactionGuardImpl.access$100(TransactionGuardImpl.java:22)
# 	at com.intellij.openapi.application.TransactionGuardImpl$1.run(TransactionGuardImpl.java:191)
# ...
# 	at com.intellij.openapi.application.impl.RwLockHolder.runWithEnabledImplicitRead(RwLockHolder.kt:75)
# 	at com.intellij.openapi.application.impl.RwLockHolder.runWithImplicitRead(RwLockHolder.kt:67)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runWithImplicitRead(ApplicationImpl.java:1436)
# 	at com.intellij.openapi.application.impl.FlushQueue.doRun(FlushQueue.java:82)
# 	at com.intellij.openapi.application.impl.FlushQueue.runNextEvent(FlushQueue.java:124)
# 	at com.intellij.openapi.application.impl.FlushQueue.flushNow(FlushQueue.java:44)
# 	at java.desktop/java.awt.event.InvocationEvent.dispatch(InvocationEvent.java:318)
# 	at java.desktop/java.awt.EventQueue.dispatchEventImpl(EventQueue.java:792)
# 	at java.desktop/java.awt.EventQueue$3.run(EventQueue.java:739)
# 	at java.desktop/java.awt.EventQueue$3.run(EventQueue.java:733)
# 	at java.base/java.security.AccessController.doPrivileged(AccessController.java:399)
# 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:86)
# 	at java.desktop/java.awt.EventQueue.dispatchEvent(EventQueue.java:761)
# 	at com.intellij.ide.IdeEventQueue.defaultDispatchEvent(IdeEventQueue.kt:695)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent$lambda$12(IdeEventQueue.kt:589)
# 	at com.intellij.openapi.application.impl.RwLockHolder.runWithoutImplicitRead(RwLockHolder.kt:44)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent(IdeEventQueue.kt:589)
# 	at com.intellij.ide.IdeEventQueue.access$_dispatchEvent(IdeEventQueue.kt:72)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.compute(IdeEventQueue.kt:355)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.compute(IdeEventQueue.kt:354)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computePrioritized(CoreProgressManager.java:793)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1.invoke(IdeEventQueue.kt:354)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1.invoke(IdeEventQueue.kt:349)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity$lambda$1(IdeEventQueue.kt:1014)
# 	at com.intellij.openapi.application.TransactionGuardImpl.performActivity(TransactionGuardImpl.java:106)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity(IdeEventQueue.kt:1014)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent$lambda$7(IdeEventQueue.kt:349)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runIntendedWriteActionOnCurrentThread(ApplicationImpl.java:848)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent(IdeEventQueue.kt:391)
# 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:207)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:128)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:117)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:113)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:105)
# 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:92)
# 15:45:37.947 INFO [LocalSessionMap.lambda$new$0] - Deleted session from local Session Map, Id: e9843a5398c39a7e9b86d420049db0c3
# 15:45:37.947 INFO [GridModel.release] - Releasing slot for session id e9843a5398c39a7e9b86d420049db0c3
# 15:45:37.950 INFO [SessionSlot.stop] - Stopping session e9843a5398c39a7e9b86d420049db0c3
# 15:45:38.120 INFO [LocalNode.stopTimedOutSession] - Session id b777b3802af4300e8a96057782162818 timed out, stopping...
# 15:45:58.260 INFO [LocalSessionMap.lambda$new$0] - Deleted session from local Session Map, Id: b777b3802af4300e8a96057782162818
# 15:45:58.260 INFO [GridModel.release] - Releasing slot for session id b777b3802af4300e8a96057782162818
# 15:45:58.260 INFO [SessionSlot.stop] - Stopping session b777b3802af4300e8a96057782162818
# 15:49:33.139 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 15:49:36.804 INFO [LocalNode.newSession] - Session created by the Node. Id: bffecf2c5cce4eccf842b17f254f1200, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:35453}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 15:49:36.814 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: bffecf2c5cce4eccf842b17f254f1200
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:35453}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
#   2024-05-30 15:49:41 ................................................... ~ 0s
#   2024-05-30 15:49:41 ................................................... ~ 0s
#   2024-05-30 15:49:41 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:49:41 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:49:42 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:49:43 ................................................... ~ 0s
#   2024-05-30 15:49:43 .................................................. ~ -1s
#   2024-05-30 15:49:44 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:49:44 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:49:45 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:49:49 .................................................. ~ -1s
#   2024-05-30 15:49:50 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:49:50 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:49:51 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:49:55 ................................................... ~ 0s
#   2024-05-30 15:49:55 .................................................. ~ -1s
#   2024-05-30 15:49:56 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:49:56 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:49:56 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:49:57 .................................................. ~ -1s
#   2024-05-30 15:49:58 ................................................... ~ 0s
#   2024-05-30 15:49:58 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:49:58 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:49:58 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:49:59 ................................................... ~ 0s
#   2024-05-30 15:49:59 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:49:59 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:49:59 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:50:00 ................................................... ~ 0s
#   2024-05-30 15:50:00 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:50:00 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:50:01 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:50:01 ................................................... ~ 0s
#   2024-05-30 15:50:01 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:50:01 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:50:01 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:50:04 ................................................... ~ 0s
#   2024-05-30 15:50:04 .................................................. ~ -1s
#   2024-05-30 15:50:05 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:50:05 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:50:05 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:50:06 ................................................... ~ 0s
#   2024-05-30 15:50:06 ................................................... ~ 0s
#   2024-05-30 15:50:06 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:50:06 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:50:06 /favicon.ico ...................................... ~ 0s
# 15:50:27.488 INFO [LocalSessionMap.lambda$new$0] - Deleted session from local Session Map, Id: bffecf2c5cce4eccf842b17f254f1200
# 15:50:27.489 INFO [GridModel.release] - Releasing slot for session id bffecf2c5cce4eccf842b17f254f1200
# 15:50:27.491 INFO [SessionSlot.stop] - Stopping session bffecf2c5cce4eccf842b17f254f1200
# 15:50:59.814 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 15:51:01.292 INFO [LocalNode.newSession] - Session created by the Node. Id: 54576c0c8c97726a1e849b93e8cba32a, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:43019}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 15:51:01.296 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: 54576c0c8c97726a1e849b93e8cba32a
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 121.0.6167.184, chrome: {chromedriverVersion: 121.0.6167.184 (057a8ae7deb..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:43019}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 121.0.6167.184, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
#   2024-05-30 15:51:04 ................................................... ~ 0s
#   2024-05-30 15:51:04 ................................................... ~ 0s
#   2024-05-30 15:51:04 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:51:04 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:05 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:51:06 ................................................... ~ 0s
#   2024-05-30 15:51:06 .................................................. ~ -1s
#   2024-05-30 15:51:07 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:51:07 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:07 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:51:07 ................................................... ~ 0s
#   2024-05-30 15:51:07 /build/assets/app-BJFZEaIV.css ................... ~ -1s
#   2024-05-30 15:51:08 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:08 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:51:10 .................................................. ~ -1s
#   2024-05-30 15:51:10 .................................................. ~ -2s
#   2024-05-30 15:51:12 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:51:12 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:13 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:51:19 ................................................... ~ 0s
#   2024-05-30 15:51:19 ................................................... ~ 0s
#   2024-05-30 15:51:19 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:51:19 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:19 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:51:20 ................................................... ~ 0s
#   2024-05-30 15:51:20 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:51:20 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:20 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:51:21 ................................................... ~ 0s
#   2024-05-30 15:51:21 /build/assets/app-BJFZEaIV.css ................... ~ -1s
#   2024-05-30 15:51:22 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:22 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:51:22 ................................................... ~ 0s
#   2024-05-30 15:51:22 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:51:22 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:22 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:51:24 .................................................. ~ -1s
#   2024-05-30 15:51:25 ................................................... ~ 0s
#   2024-05-30 15:51:25 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:51:25 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:25 /favicon.ico ...................................... ~ 0s
#   2024-05-30 15:51:25 .................................................. ~ -1s
#   2024-05-30 15:51:26 ................................................... ~ 0s
#   2024-05-30 15:51:26 /build/assets/app-BJFZEaIV.css .................... ~ 0s
#   2024-05-30 15:51:26 /build/assets/app-CrG2wnyX.js ..................... ~ 0s
#   2024-05-30 15:51:26 /favicon.ico ...................................... ~ 0s
# 15:51:46.712 INFO [LocalSessionMap.lambda$new$0] - Deleted session from local Session Map, Id: 54576c0c8c97726a1e849b93e8cba32a
# 15:51:46.713 INFO [GridModel.release] - Releasing slot for session id 54576c0c8c97726a1e849b93e8cba32a
# 15:51:46.713 INFO [SessionSlot.stop] - Stopping session 54576c0c8c97726a1e849b93e8cba32a
# 15:51:53.407 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]

# %% [markdown]
# Stop the services:

# %%
! killall php php8.3

# %%
seleniumServer.kill()

# %%
# %cd ..
# Out:
# /home/student/php_2024_piotr_powroznik/09_laravel_tdd

# %% [markdown]
# Stop database:

# %%
! docker container stop mysql
# Out:
# mysql
